# %%
#Baitap1
n = int(input("Nhập vào một số nguyên n: "))
so_gap_doi = 2 * n
print(f"Số gấp đôi của {n} là: {so_gap_doi}")
# Out:
# Số gấp đôi của 6 là: 12

# %%
#Baitap2
a = int(input("chieu dai cua khu dat la: "))
b = int(input("chieu rong cua khu dat la: "))
khuvuichoi = (b/2)*2 * 3.14
khudat = a*b 
print ("dien tich de trong cay la:" , khudat - khuvuichoi)
# Out:
# dien tich de trong cay la: 11.44

# %%
#Baitap3
c = input("nhap ki tu bat ky:")
if c.isupper():
    print(c.lower())
else:
    print(c.upper())
# Out:
# 9

# %%
#Baitap4
c = input("nhap ki tu bat ky: ")
if c.isalpha():
    print("c la ki tu alphabet")
else:
    print("c khong phai la ki tu alphabet")
# Out:
# c khong phai la ki tu alphabet

# %%
#Baitap5
c = input("nhap chu cai hoa: ")
if len(c) != 1 or not c.isalpha() or not c.isupper():
    print("hay nhap mot chu cai hoa (A-Z)")
elif c == 'A':
        print("z")
else:
    kq = chr(ord(c.lower()) - 1)
    print(kq)
# Out:
# m

# %%
#Baitap6
a, b, c = map(int, input("nhap lan luot 3 so nguyen: ").split())
if a+b>c and a+c>b and b+c>a:
    print("3 so tren la 3 canh cua tam giac")
else:
    print("3 so tren khong phai la 3 canh cua tam giac")
# Out:
# 3 so tren khong phai la 3 canh cua tam giac

# %%
#Baitap7
chuoi = str(input("nhap chuoi bat ky: "))
if len(chuoi) >= 20:
    print("ki tu thu 5 trong chuoi la:", chuoi[4])
    print("ki tu thu 9 trong chuoi la:", chuoi[8])
elif len(chuoi) < 20:
    print("chuoi khong du 20 ki tu")
# Out:
# ki tu thu 5 trong chuoi la: 3
# ki tu thu 9 trong chuoi la: 5

# %%
#Baitap8
name = input("Ten chu ho: ")
sothangtruoc = int(input("Chi so thang truoc: "))
sothangnay = int(input("Chi so thang nay: "))
so = sothangnay - sothangtruoc
if so <= 50:
    tien = (so * 1984)*1.08
    print("Ho va ten:", name)
    print("Tien phai tra la:", int(tien))
elif 50 < so <= 100:
    tien = ((50 * 1984) + (so - 50) * 2050)*1.08
    print("Ho va ten:", name)
    print("Tien phai tra la:", int(tien))
elif 100 < so <= 200:
    tien = ((50 * 1984) + (50 * 2050) + (so - 100) * 2380)*1.08
    print("Ho va ten:", name)
    print("Tien phai tra la:", int(tien))
elif 200 < so <= 300:
    tien = ((50 * 1984) + (50 * 2050) + (100 * 2380) + (so - 200) * 2998)*1.08
    print("Ho va ten:", name)
    print("Tien phai tra la:", int(tien))
elif 300 < so <= 400:
    tien = ((50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (so - 300) * 3350)*1.08
    print("Ho va ten:", name)
    print("Tien phai tra la:", int(tien))
elif so > 400:
    tien = ((50 * 1984) + (50 * 2050) + (100 * 2380) + (100 * 2998) + (100 * 3350) + (so - 400) * 3460)*1.08
    print("Ho va ten:", name)
    print("Tien phai tra la:", int(tien))
# Out:
# Ho va ten: NGUYENLEMINHNGUYEN
# Tien phai tra la: 6428

# %%
#Baithem1
a = int(input("nhap so nguyen a: "))
if a % 2 == 0:
    print(a, "la so chan")
else:
    print(a, "la so le")
# Out:
# 9 la so le

# %%
#Baithem2
a = str(input("nhap mot so nguyen: "))
count = len(a)
if a[count - 1] == str(5):
    print("True")
else:
    print("False")
# Out:
# False

# %%
#Baithem3
a = int(input("nhap so nguyen a: "))
if a % 3 == 0 and a % 5 == 0:
    print(a, "chia het cho ca 3 va 5")
else:
    print(a, "khong chia het cho ca 3 va 5")
# Out:
# 6 khong chia het cho ca 3 va 5

# %%
#Baithem4
namsinh = int(input("nhap nam sinh cua ban: "))
dieukien = 2025 - namsinh
if dieukien >= 18:
    print("ban du dieu kien tham gia bau cu")
else:
    print("ban khong du dieu kien tham gia bau cu")
# Out:
# ban du dieu kien tham gia bau cu

# %%
#Baithem5
a = int(input("nhap so nguyen a: "))
b = int(input("nhap so nguyen b: "))
if a > b:
    print("so lon hon la:", a)
elif b > a:
    print("so lon hon la:", b)
elif a == b:
    print("hai so bang nhau")
# Out:
# so lon hon la: 8

# %%
#Baithem6
a = input("nhap mot ky tu: ")
if a.isalpha():
    print(a, "la chu cai")
elif a.isdigit():
    print(a, "la chu so")
# Out:
# 4 la chu so

# %%
#Baithem7
diem = float(input("nhap diem cua ban: "))
if diem >= 8:
    print("hoc luc gioi")
elif 6.5 <= diem < 8:
    print("hoc luc kha")
elif 5 <= diem < 6.5:
    print("hoc luc trung binh")
elif diem < 5:
    print("hoc luc yeu")
# Out:
# hoc luc gioi

# %%
#Baithem8
nam = int(input("nhap nam can kiem tra: "))
if (nam % 4 == 0 and nam % 100 != 0) or (nam % 400 == 0):
    print(nam, "la nam nhuan")
else:
    print(nam, "khong phai la nam nhuan")
# Out:
# 2020 la nam nhuan

# %%
#Baithem9
a = int(input("nhap so nguyen a tu 0 toi 9: "))
b = str("Khong, Mot, Hai, Ba, Bon, Nam, Sau, Bay, Tam, Chin").split(", ")
if 0 <= a <= len(b):
    print(str(b[a]))
else:
    print("so ngoai pham vi")
# Out:
# Sau

# %%
#Baithem10
diemthi = float(input("nhap diem thi: "))
if diemthi >= 4:
    print("qua mon")
else:
    print("hoc lai")
# Out:
# qua mon

# %%
#Baithem11
namsinh = int(input("nhap nam sinh cua ban: "))
tuoi = 2025 - namsinh
if tuoi >= 18:
    print("ban da du 18 tuoi")
else:
    print("ban chua du 18 tuoi")
# Out:
# ban da du 18 tuoi
