# %%
#Baitap1
print("Hello World !!!")
# Out:
# Hello World !!!

# %%
#Baitap2
name = input("Nhap ten cua ban: ")
print(name)
# Out:
# Nguyen

# %%
#Baitap3
c = input("nhap 1 so c:")
d = input("nhap 1 so d:")
print("tong 2 so la:", int(c) + int(d))
print("hieu 2 so la:", int(c) - int(d))
print("tich 2 so la:", int(c) * int(d))
print("thuong 2 so la:", int(c) // int(d))
print("chia lay du 2 so la:", int(c) % int(d))
# Out:
# tong 2 so la: 9
# hieu 2 so la: -3
# tich 2 so la: 18
# thuong 2 so la: 0
# chia lay du 2 so la: 3

# %%
#Baitap4
a1, b1, c1, a2, b2, a3 = map(int, input("nhap lan luot cac diem:").split())
diemtrungbinh = ((a1 + b1 + c1 + (a2+b2)*2 + a3*3)/10)
print("diem trung binh la:", diemtrungbinh)
# Out:
# diem trung binh la: 7.1

# %%
#Baitap5
c, d = map(int, input("nhap so c va d:").split())
print("luy thua mu d cua c la:", int(c**d))
# Out:
# luy thua mu d cua c la: 729

# %%
#Baitap6
a = input("nhap mot chu cai thuong (a-z): ")
if len(c) != 1 or not c.isalpha() or not c.islower():
    print("hay nhap mot chu cai thuong")
else:
    unicode_code = ord(c)
    print("ma unicode cua ", c, "la:", unicode_code)
    
    uppercase_char = c.upper()
    print("Ki tu hoa tuong ung la:", uppercase_char)
# Out:
# ma unicode cua  n la: 110
# Ki tu hoa tuong ung la: N

# %%
#Baitap7
C=((13 ** 2) * 3) + 5
D=13**2*3 + 5
print(C, D)
# Out:
# 512 512

# %%
#Baitap8
A=int(input("nhap nhiet do A:"))
F=9/5 * C + 32
print("nhiet do F la:", F)
# Out:
# nhiet do F la: 953.6

# %%
#Baitap9
usd = int(input("nhap gia tien dong ho:"))
tien= usd + 10 + usd*40/100
print("gia tien dong ho ma Dat phai tra la:", tien)
# Out:
# gia tien dong ho ma Dat phai tra la: 420010.0

# %%
#Baitap10
name=input("nhap ten 3 nguoi bat ky:").split()
print(name[2], name[1], name[0])
# Out:
# PHUONG QUYNH NGUYEN

# %%
#Baitap11
h, m = map(int, input("nhap gio va phut:").split())
s = h * 3600 + m * 60
print(h, "va", m, "doi ra giay la:", s)
# Out:
# 3 va 6 doi ra giay la: 11160

# %%
#Baitap12
n = int(input("nhap so canh cua rubik:"))
miengdan = n**2 * 6
print("so mieng dan can de dan cho rubik la:", miengdan)
# Out:
# so mieng dan can de dan cho rubik la: 864

# %%
#Baitap13
m = int(input("nhap so m: "))
n = int(input("nhap so n: "))
c = str(m*n)
print("chu so cuoi cung cua tich m va n la:", c[-1])
# Out:
# chu so cuoi cung cua tich m va n la: 8

# %%
#Baitap14
m = int(input("nhap so m: "))
n = int(input("nhap so n: "))
m, n = n, m
print("Sau khi hoan doi: m =", m, ", n =", n)
# Out:
# Sau khi hoan doi: m = 3 , n = 6

# %%
#Baitap15
m = int(input("nhap so nguyen duong m: "))
if m <= 0:
    print("hay nhap so nguyen duong")
else:
    so_sao = 6 * m * (m - 1) + 1
    print("So sao thu", m, "la:", so_sao)
# Out:
# So sao thu 6 la: 181

# %%
#Baitap16
print("Spring\nSummer\nFall\nWinter")
# Out:
# Spring
# Summer
# Fall
# Winter

# %%
#Baitap17
print("*\n***\n*****")
# Out:
# *
# ***
# *****

# %%
#Baitap18
print("### # # #    ###  ###")  
print(" #    #   #   #    #  ")
print(" #    #    #  #    #  ")
print(" #    #   #   #    #  ")
print(" #    # #     #    #")
# Out:
# ### # # #    ###  ###
#  #    #   #   #    #
#  #    #    #  #    #
#  #    #   #   #    #
#  #    # #     #    #

# %%
#Baitap19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#Baitap20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#Baitap21
for n in range (10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
